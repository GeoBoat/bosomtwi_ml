# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sns.set(style='whitegrid', palette="deep", font_scale=1.1, rc={"figure.figsize": [8, 5]})

# %% [markdown]
# ## LB-07A

# %%
lb07A = pd.read_csv('datasets/LB-07A.csv')
lb07A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 424 entries, 0 to 423
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   depth        424 non-null    float64
#  1   density      424 non-null    float64
#  2   mag_suscep   419 non-null    float64
#  3   scaler_tmi   371 non-null    float64
#  4   total_gamma  372 non-null    float64
#  5   caliper      367 non-null    float64
#  6   lithology    424 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 23.3+ KB

# %%
lb07A.dropna(inplace=True)
lb07A["lithology"] = lb07A["lithology"].astype("str")
lb07A.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 363 entries, 21 to 383
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   depth        363 non-null    float64
#  1   density      363 non-null    float64
#  2   mag_suscep   363 non-null    float64
#  3   scaler_tmi   363 non-null    float64
#  4   total_gamma  363 non-null    float64
#  5   caliper      363 non-null    float64
#  6   lithology    363 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 22.7+ KB

# %%
lb07A.hist(bins=15, figsize=(20,9), layout=(2, 4))
# Out:
# array([[<AxesSubplot: title={'center': 'depth'}>,
#         <AxesSubplot: title={'center': 'density'}>,
#         <AxesSubplot: title={'center': 'mag_suscep'}>,
#         <AxesSubplot: title={'center': 'scaler_tmi'}>],
#        [<AxesSubplot: title={'center': 'total_gamma'}>,
#         <AxesSubplot: title={'center': 'caliper'}>, <AxesSubplot: >,
#         <AxesSubplot: >]], dtype=object)

# %%
fig, ax = plt.subplots(2, 3, figsize=(20, 9))

for property, subplot in zip(lb07A.columns, ax.flatten()):

    sns.boxplot(x=lb07A[property], ax=subplot)

# %%
sns.pairplot(lb07A.drop(["depth"], axis=1), hue="lithology")

# %%
lb07A_corr = lb07A.corr()
mask = np.triu(np.ones_like(lb07A_corr, dtype=bool))
fig, ax = plt.subplots(figsize=(5, 5))
cmap = sns.diverging_palette(230, 20, as_cmap=True)
sns.heatmap(lb07A_corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# C:\Users\steve\AppData\Local\Temp\ipykernel_16880\1670008132.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   lb07A_corr = lb07A.corr()
# <AxesSubplot: >

# %%
sns.countplot(x=lb07A["lithology"])
# Out:
# <AxesSubplot: xlabel='lithology', ylabel='count'>
